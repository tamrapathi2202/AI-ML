# %%
# Check Python version
import sys
print("Python version:", sys.version)
 
# Check installed modules
help("modules")
 
# Quick version compare
if sys.version_info >= (3, 10):
    print("✅ You’re on a modern Python version!")
else:
    print("⚠ Consider Upgrading Python.")
# Out:
# Python version: 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]
#
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with SQLite version 3.45.3
# 30fcd23745efe32ce681__mypyc _win32sysloader     jupyter_client      stringprep
# IPython             _win32verstamp_pywin32ctypes jupyter_core        struct
# __future__          _winapi             keyword             subprocess
# __hello__           _winxptheme         linecache           symtable
# __phello__          _wmi                locale              sys
# _abc                _zoneinfo           logging             sysconfig
# _aix_support        abc                 lzma                tabnanny
# _android_support    adodbapi            mailbox             tarfile
# _apple_support      afxres              marshal             tempfile
# _ast                antigravity         math                test
# ...

# %%
from IPython.display import Image, display

images = ['pic1.png.png', 'pic2.png.png', 'pic3.png.png', 'pic4.png.png', 'pic5.png.png', 'pic6.png.png', 'pic7.png.png', 'pic8.png.png', 'pic9.png.png', 'pic10.png.png', 'pic11.png.png']  # list of image files

for imgs in images:
    display(Image(filename=imgs))
